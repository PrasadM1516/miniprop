# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_data.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.size
# Out:
# 13035

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.scatterplot(x='age',y='failures',data=df)
# Out:
# <Axes: xlabel='age', ylabel='failures'>

# %%
upper_limit = df['age'].mean() + 3 *df['age'].std() 
print("Upper limit of data:",upper_limit)
# Out:
# Upper limit of data: 20.524330705462454

# %%
lower_limit = df['age'].mean() - 3 *df['age'].std() 
print("Lower limit of data:",lower_limit)
# Out:
# Lower limit of data: 12.868074357828682

# %%
z_outlier = df[(df['age']>upper_limit) | (df['age']<lower_limit)]
print(z_outlier)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 247     GP   M   22       U     GT3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1 G2 G3
# 247  ...      5        4      5     5     5      1       16   6  8  8
# 392  ...      5        5      3     3     3      3        3  10  8  7
#
# [2 rows x 33 columns]

# %%
df['age'].plot.box()
# Out:
# <Axes: >

# %%
df['age'].loc[(df['age']>upper_limit) | (df['age']<lower_limit)]
# Out:
# 247    22
# 392    21
# Name: age, dtype: int64

# %%
new_df = df.loc[(df['age']<upper_limit) & (df['age']>lower_limit)]
new_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
len(df)
# Out:
# 395

# %%
len(new_df)
# Out:
# 393

# %%
num_outliers = len(df)-len(new_df)
print("No of outliers:",num_outliers)
# Out:
# No of outliers: 2

# %%
sns.boxplot(new_df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
cap_df = df.copy()

# %%
cap_df.loc[(cap_df['age']>upper_limit),'age'] = upper_limit
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_18452\1825743566.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '20.524330705462454' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   cap_df.loc[(cap_df['age']>upper_limit),'age'] = upper_limit

# %%
cap_df.loc[(cap_df['age']<lower_limit),'age'] = lower_limit

# %%
cap_df
# Out:
#     school sex        age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0       GP   F  18.000000       U     GT3       A     4     4   at_home
# 1       GP   F  17.000000       U     GT3       T     1     1   at_home
# 2       GP   F  15.000000       U     LE3       T     1     1   at_home
# 3       GP   F  15.000000       U     GT3       T     4     2    health
# 4       GP   F  16.000000       U     GT3       T     3     3     other
# ..     ...  ..        ...     ...     ...     ...   ...   ...       ...
# 390     MS   M  20.000000       U     LE3       A     2     2  services
# 391     MS   M  17.000000       U     LE3       T     3     1  services
# 392     MS   M  20.524331       R     GT3       T     1     1     other
# 393     MS   M  18.000000       R     LE3       T     3     2  services
# 394     MS   M  19.000000       U     LE3       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  \
# ...

# %%
sns.boxplot(cap_df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
dff = df.copy()

# %%
Q1 = np.percentile(dff['age'],25, interpolation='midpoint')
Q2 = np.percentile(dff['age'],50, interpolation='midpoint')
Q3 = np.percentile(dff['age'],75, interpolation='midpoint')

print("Q1 25th percentile of given data is:",Q1)
print("Q2 50th percentile of given data is:",Q2)
print("Q3 75th percentile of given data is:",Q3)

IQR = Q3 - Q1
print("Interquartile range = ",IQR)
# Out:
# Q1 25th percentile of given data is: 16.0
# Q2 50th percentile of given data is: 17.0
# Q3 75th percentile of given data is: 18.0
# Interquartile range =  2.0

# %%
low_lim = Q1 - 1.5*IQR
up_lim = Q3 + 1.5*IQR
print("Lower limit:",low_lim)
print("Upper limit:",up_lim)
# Out:
# Lower limit: 13.0
# Upper limit: 21.0

# %%
from sklearn.preprocessing import MinMaxScaler
mns = MinMaxScaler()

# %%
df['age'] = mns.fit_transform(df[['age']])

# %%
df
# Out:
#     school sex       age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0       GP   F  0.428571       U     GT3       A     4     4   at_home
# 1       GP   F  0.285714       U     GT3       T     1     1   at_home
# 2       GP   F  0.000000       U     LE3       T     1     1   at_home
# 3       GP   F  0.000000       U     GT3       T     4     2    health
# 4       GP   F  0.142857       U     GT3       T     3     3     other
# ..     ...  ..       ...     ...     ...     ...   ...   ...       ...
# 390     MS   M  0.714286       U     LE3       A     2     2  services
# 391     MS   M  0.285714       U     LE3       T     3     1  services
# 392     MS   M  0.857143       R     GT3       T     1     1     other
# 393     MS   M  0.428571       R     LE3       T     3     2  services
# 394     MS   M  0.571429       U     LE3       T     1     1     other
#
#          Fjob  ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  \
# ...
